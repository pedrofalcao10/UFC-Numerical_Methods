# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## *Teorema de Bolzano*

# %%
def bolzano(f, a, b):
  return f(a)*f(b) < 0

# %% [markdown]
# ## *Método da bissecção*

# %%
def bissection(f, a, b, e, maxiter):
    i = 1
    x = (a + b) / 2

    while i <= maxiter:
        if f(x) == 0:
            return x, f(x)

        if abs(b - a) < e:
            break

        if bolzano(f, a, x):
            b = x
        elif bolzano(f, x, b):
            a = x

        x_ant = x
        x = (a + b) / 2
        erro = abs(x - x_ant) / abs(x)
        print(f'iteração:{i}, raiz:{x}, f(x):{f(x)}, erro:{erro}')

        i += 1

    return x, f(x)

# %% [markdown]
# ### *Estimador de iterações p/ método da bissecção*

# %%
def estimate_iterations(a, b, e):
  return math.ceil(((math.log(b - a)) - (math.log(e))) / (math.log(2)))

# %% [markdown]
# ## *Método da falsa posição*

# %%
def false_position(f, a, b, e, max_Iter):
    i = 1
    x = (a * f(b) - b * f(a)) / (f(b) - f(a))
    erro = abs(x - a) / abs(x)

    while i <= max_Iter and erro > e:
        fx = f(x)

        if fx == 0:
            return x, fx

        if bolzano(f, a, x):
            b = x
        elif bolzano(f, x, b):
            a = x

        x_ant = x
        x = (a * f(b) - b * f(a)) / (f(b) - f(a))
        erro = abs(x - x_ant) / abs(x)

        print(f'iteração:{i}, raiz:{x}, f(x):{fx}, erro:{erro}')
        i += 1

    return x, f(x)

# %% [markdown]
# ## *Método do ponto-fixo*

# %%
def fix_point(f, g, x0, e=1e-10, maxiter=100):
    i = 1

    while i <= maxiter:
        x1 = g(x0)
        erro_perc = abs(x1 - x0) / abs(x1)

        print(f'iteração:{i}, raiz:{x1}, f(x):{f(x1)}, erro:{erro_perc}')

        if erro_perc <= e:
            break

        x0 = x1
        i += 1

    return x1, f(x1)

# %% [markdown]
# ## *Método de Newton-Raphson*

# %%
def newton_raphson(f, dfdx, x0, e=1e-10, maxiter=100):
    i = 1

    while i <= maxiter:
        xr = x0 - f(x0) / dfdx(x0)
        erro_perc = abs(xr - x0) / abs(x0)

        print(f'iteração:{i}, raiz:{xr}, f(x):{f(xr)}, erro:{erro_perc}')

        if erro_perc <= e:
            break

        x0 = xr
        i += 1

    return xr, f(xr)

# %% [markdown]
# ## *Método das Secantes*

# %%
def secants(f, x0, x1, e=1e-10, maxiter=100):
    i = 1

    while i <= maxiter:
        xr = x0 - f(x0) / ((f(x0) - f(x1)) / (x0 - x1))
        erro_perc = abs(xr - x0) / abs(x0)

        print(f'iteração:{i}, raiz:{xr}, f(x):{f(xr)}, erro:{erro_perc}')

        if erro_perc <= e:
            break

        x1, x0 = x0, xr
        i += 1

    return xr, f(xr)

# %% [markdown]
# ### *Método das Secantes com análise de casas decimais*

# %%
def secants_sig(f, x0, x1, alg_sig, e=1e-10, maxiter=100):
    i = 1
    delta_x = 10**(-1 * (alg_sig + 1))

    while i <= maxiter:
        xr = x0 - f(x0) / ((f(x0) - f(x1)) / (x0 - x1))
        erro_perc = abs(xr - x0) / abs(x0)

        print(f'iteração:{i}, raiz:{xr}, f(x):{f(xr)}, erro:{erro_perc}')

        if abs(xr - x0) <= delta_x:
            break

        x1, x0 = x0, xr
        i += 1

    return xr, f(xr)

# %% [markdown]
# ### *Método de Muller*

# %%
import cmath

def mullers_method(f, x0, x1, x2, tol=1e-6, max_iter=100):
    iter_count = 0

    while iter_count < max_iter:
        # Compute the coefficients of the parabola
        f0, f1, f2 = f(x0), f(x1), f(x2)
        h1, h2 = x1 - x0, x2 - x1
        d1, d2 = (f1 - f0) / h1, (f2 - f1) / h2
        a = (d2 - d1) / (h2 + h1)
        b = a * h2 + d2
        c = f2

        # Compute the root approximation using the quadratic formula
        delta = cmath.sqrt(b**2 - 4*a*c)
        if abs(b - delta) < abs(b + delta):
            den = b + delta
        else:
            den = b - delta
        dxr = -2 * c / den
        xr = x2 + dxr

        # Check for convergence
        if abs(xr - x2)/xr < tol:
            return xr

        # Update the points for the next iteration
        x0, x1, x2 = x1, x2, xr
        iter_count += 1

    raise Exception("Maximum number of iterations reached")

# You can use the function like this:
# Define the function for which you want to find the root

# root = mullers_method(f1, -1, 0, 1)
# print(root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1b7ed73e4228> in <cell line: 37>()
#      35 # Define the function for which you want to find the root
#      36
# ---> 37 root = mullers_method(f1, -1, 0, 1)
#      38 print(root)
#
# NameError: name 'f1' is not defined

# %% [markdown]
# ## *Busca Intervalar*

# %%
def encontra_intervalo(inicio, xmax, passo, f):
    refi = inicio

    while passo > 1e-4:
        final = inicio + passo

        if f(inicio) * f(final) < 0:
            return inicio, final

        inicio = final

        if final >= xmax:
            break

    inicio = refi
    passo /= 10

    return None

# %% [markdown]
# ## *Busca Multi-Intervalar*

# %%
def encontra_varios_intervalos(inicio, xmax, passo, f):
    vet_inicio = []
    vet_final = []

    while passo > 1e-4:
        inicio_temp = inicio

        while inicio_temp < xmax:
            final = inicio_temp + passo

            if f(inicio_temp) * f(final) < 0:
                vet_inicio.append(inicio_temp)
                vet_final.append(final)

            inicio_temp = final

        if vet_inicio:
            return vet_inicio, vet_final

        passo /= 10

    return vet_inicio, vet_final
